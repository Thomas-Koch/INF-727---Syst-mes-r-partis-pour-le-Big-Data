# %% [markdown]
# # Etape 2 et 3

# %%
chronos@localhost / $ ssh tkoch@c125-02
c125-02% hostname                    
c125-02
c125-02% hostname --long
c125-02.enst.fr
c125-02% hostname -I                  
137.194.35.194 2001:660:330f:22:16b3:1fff:fe0f:3f30 
c125-02% /sbin/ifconfig               
eth0: flags=4163<UP,BROADCAST,RUNNING,MULTICAST>  mtu 1500
        inet 137.194.35.194  netmask 255.255.254.0  broadcast 137.194.35.255
        inet6 2001:660:330f:22:16b3:1fff:fe0f:3f30  prefixlen 64  scopeid 0x0<global>
        inet6 fe80::16b3:1fff:fe0f:3f30  prefixlen 64  scopeid 0x20<link>
        ether 14:b3:1f:0f:3f:30  txqueuelen 1000  (Ethernet)
        RX packets 59213  bytes 32367846 (30.8 MiB)
        RX errors 0  dropped 0  overruns 0  frame 0
        TX packets 38303  bytes 26251590 (25.0 MiB)
        TX errors 0  dropped 0 overruns 0  carrier 0  collisions 0
        device interrupt 20  memory 0xf7000000-f7020000  

lo: flags=73<UP,LOOPBACK,RUNNING>  mtu 65536
        inet 127.0.0.1  netmask 255.0.0.0
        inet6 ::1  prefixlen 128  scopeid 0x10<host>
        loop  txqueuelen 1  (Boucle locale)
        RX packets 381  bytes 29666 (28.9 KiB)
        RX errors 0  dropped 0  overruns 0  frame 0
        TX packets 381  bytes 29666 (28.9 KiB)
        TX errors 0  dropped 0 overruns 0  carrier 0  collisions 0

vmtp: flags=4163<UP,BROADCAST,RUNNING,MULTICAST>  mtu 1500
        ether 14:b3:1f:0f:3f:30  txqueuelen 1000  (Ethernet)
        RX packets 3580  bytes 165370 (161.4 KiB)
        RX errors 0  dropped 0  overruns 0  frame 0
        TX packets 0  bytes 0 (0.0 B)
        TX errors 0  dropped 0 overruns 0  carrier 0  collisions 0

c125-02% iconfig 
zsh: correct 'iconfig' to '_iwconfig' [nyae]? y
_arguments:comparguments:319: can only be called from completion function
c125-02% nslookup 137.194.120.191     
Server:         137.194.2.34
Address:        137.194.2.34#53

** server can't find 191.120.194.137.in-addr.arpa: NXDOMAIN

c125-02% nslookup                
> ^C%                                                                                c125-02% dig -x 137.194.35.196 +short
c125-04.enst.fr.
c125-02% dig -x 137.194.35.196       

; <<>> DiG 9.10.3-P4-Debian <<>> -x 137.194.35.196
;; global options: +cmd
;; Got answer:
;; ->>HEADER<<- opcode: QUERY, status: NOERROR, id: 50941
;; flags: qr aa rd ra; QUERY: 1, ANSWER: 1, AUTHORITY: 3, ADDITIONAL: 6

;; OPT PSEUDOSECTION:
; EDNS: version: 0, flags:; udp: 4096
;; QUESTION SECTION:
;196.35.194.137.in-addr.arpa.   IN      PTR

;; ANSWER SECTION:
196.35.194.137.in-addr.arpa. 86400 IN   PTR     c125-04.enst.fr.

;; AUTHORITY SECTION:
194.137.in-addr.arpa.   86400   IN      NS      ns-auth1.enst.fr.
194.137.in-addr.arpa.   86400   IN      NS      diamant.int-evry.fr.
194.137.in-addr.arpa.   86400   IN      NS      ns-auth2.enst.fr.

;; ADDITIONAL SECTION:
diamant.int-evry.fr.    16647   IN      A       157.159.10.12
ns-auth1.enst.fr.       86400   IN      A       137.194.2.156
ns-auth1.enst.fr.       86400   IN      AAAA    2001:660:330f:2::9c
ns-auth2.enst.fr.       86400   IN      A       137.194.2.157
ns-auth2.enst.fr.       86400   IN      AAAA    2001:660:330f:2::9d

;; Query time: 0 msec
;; SERVER: 137.194.2.34#53(137.194.2.34)
;; WHEN: Wed Sep 25 14:14:32 CEST 2019
;; MSG SIZE  rcvd: 266

c125-02% host c125-02                
c125-02.enst.fr has address 137.194.35.194
c125-02% host c125-04
c125-04.enst.fr has address 137.194.35.196
c125-02% _iwconfig                   
_arguments:comparguments:319: can only be called from completion function
c125-02% calc 3+5                    
        8
c125-02% echo $((3+5))               
8
c125-02% ssh c125-08 calc 3+5
        8
c125-02% ssh c125-08 ssh c125-04 calc 3+5
        8
c125-02% pwd
/cal/homes/tkoch
c125-02% touch fperso.txt  #permet de créer un fichier fperso.txt
c125-02% nano fperso.txt #permet d'accéder au fichier txt que l'on vient de créer et le modifier avec nano
c125-02% ls
Desktop    fperso.txt       thinclient_drives  workspace
Downloads  Téléchargements  TP Stat Python     workspace.7z

c125-02% ls -l fperso.txt
-rw-r--r-- 1 tkoch eleves 8 sept. 25 14:22 fperso.txt

c125-02% df -k fperso.txt
Sys. de fichiers                     blocs de 1K Utilisé Disponible Uti% Monté sur
zfs-b232.enst.fr:/export/homes/tkoch     3145728  286720    2859008 10% /cal/homes/tkoch

c125-02% cd /tmp      
c125-02% ls
ftmp.txt
krb5cc_33838_FHa68P
krb5cc_36204_Txphzz
krb5cc_37883_Fqk6hi
krb5cc_37927_PDNoTr
krb5cc_38320_tdvCO2
krb5cc_38660_fifDrQ
krb5cc_38663_l0d9t3
krb5cc_39536_gm4UHU
krb5cc_39672_jJZoSm
krb5ccmachine_ENST.FR
krb5cc_pam_Bukoew
pulse-PKdhtXMmr18n
systemd-private-d4934cf51008426e8a874eabdc253031-lldpd.service-cNm73K
xrand.log
c125-02% ls -l
total 64K
-rw-r--r-- 1 nlouis   eleves    0 sept. 25 14:30 fperso.txt
-rw-r--r-- 1 zduan    eleves    0 sept. 25 14:27 ftmp.txt
-rw------- 1 nlouis   eleves 1,5K sept. 25 14:16 krb5cc_33838_FHa68P
-rw------- 1 simoneau eleves 2,5K sept. 25 14:13 krb5cc_36204_Txphzz
-rw------- 1 zduan    eleves 1,5K sept. 25 14:16 krb5cc_37883_Fqk6hi
-rw------- 1 cvuillet eleves 1,6K sept. 25 14:11 krb5cc_37927_PDNoTr
-rw------- 1 sdavid   eleves 1,5K sept. 25 14:16 krb5cc_38320_tdvCO2
-rw------- 1 lehericy eleves 1,6K sept. 25 14:15 krb5cc_38660_fifDrQ
-rw------- 1 xu       eleves 1,5K sept. 25 14:16 krb5cc_38663_l0d9t3
-rw------- 1 tkoch    eleves 2,5K sept. 25 14:16 krb5cc_39536_gm4UHU
-rw------- 1 gsavoure eleves 1,6K sept. 25 14:10 krb5cc_39672_jJZoSm
-rw------- 1 root     root   1,6K sept. 25 13:49 krb5ccmachine_ENST.FR
-rw------- 1 root     eleves  506 sept. 25 14:00 krb5cc_pam_Bukoew
drwx------ 2 root     root   4,0K sept. 25 13:49 pulse-PKdhtXMmr18n
drwxr-xr-x 2 sdavid   eleves 4,0K sept. 25 14:30 sdavid
drwx------ 3 root     root   4,0K sept. 25 13:49 systemd-private-d4934cf51008426e8a874eabdc253031-lldpd.service-cNm73K
-rw-r--r-- 1 root     root   1,2K sept. 25 13:51 xrand.log
drwxr-xr-x 2 zduan    eleves 4,0K sept. 25 14:31 zduan
c125-02% mkdir tkoch
c125-02% cd /tmp/tkoch
c125-02% ssh c125-11 mkdir /tmp/tkoch #permet de créer le même dossier sur la machine c125-11
c125-02% ssh c125-11                     
Linux c125-11 4.9.0-11-amd64 #1 SMP Debian 4.9.189-3 (2019-09-02) x86_64

The programs included with the Debian GNU/Linux system are free software;
the exact distribution terms for each program are described in the
individual files in /usr/share/doc/*/copyright.

Debian GNU/Linux comes with ABSOLUTELY NO WARRANTY, to the extent
permitted by applicable law.
c125-11% cd /tmp/tkoch
c125-11% ssh c125-08 mkdir /tmp/tkoch
c125-11% touch fichier
c125-11% ls
fichier
c125-11% cat fichier
c125-11% nano fichier
c125-11% cat fichier 
cdsvfvfdsv
c125-11% scp fichier c125-08:/tmp/tkoch  #permet de copier 'fichier' vers c125-08 dans le répertoire spécifié
fichier                                            100%   11    12.3KB/s   00:00 
c125-11% ssh c125-08 cat /tmp/tkoch/fichier
cdsvfvfdsv

c125-11% ssh c125-04 cat /tmp/tkoch/fichier
cat: /tmp/tkoch/fichier: Aucun fichier ou dossier de ce type
c125-11% scp fichier c125-08:/tmp/tkoch/fichier c125-04:/tmp/tkoch
scp: /tmp/tkoch: No such file or directory
c125-11% ssh c125-04 mkdir /tmp/tkoch
c125-11% scp fichier c125-08:/tmp/tkoch/fichier c125-04:/tmp/tkoch
fichier                                            100%   11    12.4KB/s   00:00    
c125-11% ssh c125-04 cat /tmp/tkoch/fichier                   
cdsvfvfdsv

c125-11% scp -r c125-08:/tmp/tkoch c125-02:/tmp #permet de copier tout le répertoire
c125-11% ssh c125-02 cat /tmp/tkoch/fichier
cdsvfvfdsv
c125-11% ssh c125-02 ls /tmp/tkoch
fichier

# %% [markdown]
# # Etape 4 : lancer des programmes java à distance manuellement

# %%
# Programme SLAVE 

import java.io.IOException;

public class Slave {

	public static void main(String args[]) throws IOException {
		int a = 3+5 ;
        System.out.println(a);
    	
	}
}



chronos@localhost / $ sudo enter-chroot
Password: 
Entering /mnt/stateful_partition/crouton/chroots/xenial...
(base) (xenial)p5hngk@localhost:~$ cd /tmp/tkoch
(base) (xenial)p5hngk@localhost:/tmp/tkoch$ ls
SLAVE.jar
(base) (xenial)p5hngk@localhost:/tmp/tkoch$ java SLAVE.jar
Erreur : impossible de trouver ou charger la classe principale SLAVE.jar
(base) (xenial)p5hngk@localhost:/tmp/tkoch$ java -jar SLAVE.jar  #permet de lancer le jar (exécutable) que l'on vient de créer
8
(base) (xenial)p5hngk@localhost:/tmp/tkoch$ 
(base) (xenial)p5hngk@localhost:/tmp/tkoch$ scp SLAVE.jar ssh tkoch@c125-02:/tmp/tkoch
tkoch@c125-02's password: 
SLAVE.jar                                                                                                                               100%  671     0.7KB/s   00:00    
ssh: No such file or directory
(base) (xenial)p5hngk@localhost:/tmp/tkoch$ ssh tkoch@c125-02 ls /tmp/tkoch
tkoch@c125-02's password: 
fichier
SLAVE.jar

#Question 3.4

-rw-r--r--.  1 p5hngk p5hngk  23530 sept. 25 14:10 Xorg.crouton.1.log
-rw-r--r--.  1 p5hngk p5hngk  23602 sept. 25 14:06 Xorg.crouton.1.log.old
-rw-r--r--.  1 p5hngk p5hngk  23530 sept. 25 15:21 Xorg.crouton.2.log
-rw-r--r--.  1 p5hngk p5hngk  23602 sept. 25 14:01 Xorg.crouton.2.log.old
-rw-r--r--.  1 p5hngk p5hngk  23602 sept. 25 16:09 Xorg.crouton.3.log


    
# Programme MASTER 5.1

import java.io.IOException;

public class Master {
	
	public static void main(String args[]) throws IOException {
	
	ProcessBuilder pb = new ProcessBuilder("ls", "-al", "/tmp"); 
#	pb.inheritIO();
#	pb.start();
#	// pb.redirectError();
#	// pb.redirectErrorStream(true);
#	// pb.redirectOutput();
	
	}
}


    
# Programme MASTER 5.2 et 5.3

import java.io.IOException;

public class Master {
	
	public static void main(String args[]) throws IOException {
	
	ProcessBuilder pb = new ProcessBuilder("java", "-jar", "/tmp/tkoch/SLAVE.jar"); // ou dans le répertoire /home/p5hngk/Downloads/SLAVE.jar
	pb.inheritIO();
	pb.start();
#	// pb.redirectError();
#	// pb.redirectErrorStream(true);
#	// pb.redirectOutput();
	
	}
}

# %% [markdown]
# # Etape 6 : gérer les timeout du MASTER

# %%
# Un SLAVE qui simule un calcul de 10 secondes

import java.io.IOException;

public class Slave {

	public static void main(String args[]) throws IOException, InterruptedException {
		int a = 3+5 ;
		Thread.sleep(10000);
        System.out.println(a);
    	
	}
}

# Copie et test du nouveau SLAVE

(base) (xenial)p5hngk@localhost:/tmp/tkoch$ cd ~/Downloads
(base) (xenial)p5hngk@localhost:~/Downloads$ ls
SLAVE.jar
(base) (xenial)p5hngk@localhost:~/Downloads$ cp SLAVE.jar /tmp/tkoch
(base) (xenial)p5hngk@localhost:~/Downloads$ cd /tmp/tkoch
(base) (xenial)p5hngk@localhost:/tmp/tkoch$ ls
SLAVE.jar
(base) (xenial)p5hngk@localhost:/tmp/tkoch$ java -jar SLAVE.jar
8

# MASTER lance bien le nouveau SLAVE sans problèmes


# Gestion des timeout au niveau du master
import java.io.IOException;
import java.util.concurrent.TimeUnit;

public class Master {

	public static void main(String[] args) throws IOException, InterruptedException { 

		int timeout = Integer.parseInt(args[0]); // pour tester le programme, aller dans Run->Run configurations->Onglet Arguments->rentrer le nombre du timeout voulu

		ProcessBuilder pb = new ProcessBuilder("java", "-jar", "/tmp/tkoch/SLAVE.jar"); // ou dans le répertoire /home/p5hngk/Downloads/SLAVE.jar
		pb.inheritIO();
		Process proc = pb.start();
		boolean ret = proc.waitFor(timeout, TimeUnit.SECONDS); // permet de renvoyer true ou false pour savoir si le timeout est arrivé au bout avant que le process ne soit fini ou pas
		if (ret) {
			System.out.println("Pas de timeout, le process est allé à son terme");
		}
		else {
			System.out.println("Timeout, le process a été stoppé avant son terme");
			proc.destroy();
		}

	}
}

# Test 3 pour la gestion des timeout avec modification de SLAVE
import java.io.IOException;

public class Slave {

	public static void main(String args[]) throws IOException, InterruptedException {
		int a = 3+5 ;
		Thread.sleep(10000);
        System.err.println(a);
    	
	}
}

# %% [markdown]
# # Etape 7 : déployer automatiquement le programme SLAVE sur un ensemble de machines
